# %%
import pandas as pd

df = pd.read_csv("/content/synthetic_support_tickets_unique.csv")

print(df.shape)
df.head()
# Out:
# (1000, 11)
#   ticket_id customer_id          ticket_date  account_age_days  \
# 0    T00000       C4896  2025-11-06 02:10:45              1721
# 1    T00001       C5618  2025-10-30 19:14:40               282
# 2    T00002       C5908  2025-11-27 21:36:16               903
# 3    T00003       C3490  2025-10-18 08:31:02              1274
# 4    T00004       C7689  2025-11-15 15:26:34              1375
#
#    num_prev_tickets  avg_response_time_prev product_category issue_type  \
# 0                 1                   46.88           Beauty   Delivery
# 1                 1                   44.63      Electronics     Refund
# 2                 0                   27.51      Electronics      Other
# 3                 5                   23.47         Clothing   Delivery
# 4                 3                   23.60         Clothing      Other
#
#   priority                                        ticket_text  urgent_flag
# 0   Medium  Subject: Beauty item delivery issue Dear Suppo...            0
# 1      Low  I purchased an Electronics item on your websit...            0
# 2   Medium  "I recently purchased an Electronics item from...            0
# 3     High  Subject: Urgent Delivery Issue for Clothing It...            1
# 4     High  Subject: Urgent: Problem with Clothing item - ...            1

# %%
df[["account_age_days", "num_prev_tickets", "avg_response_time_prev"]].head()
# Out:
#    account_age_days  num_prev_tickets  avg_response_time_prev
# 0              1721                 1                   46.88
# 1               282                 1                   44.63
# 2               903                 0                   27.51
# 3              1274                 5                   23.47
# 4              1375                 3                   23.60

# %%
# Account Age Bucket

def bucket_account_age(days):
    if days < 90:
        return "New"
    elif days <= 365:
        return "Medium"
    else:
        return "Long"

df["account_age_category"] = df["account_age_days"].apply(bucket_account_age)

# Customer Activity Risk
def activity_risk(row):
    tickets = row["num_prev_tickets"]
    response = row["avg_response_time_prev"]

    if tickets >= 4 or response >= 36:
        return "High"
    elif tickets >= 2 or response >= 24:
        return "Medium"
    else:
        return "Low"

df["activity_level"] = df.apply(activity_risk, axis=1)


df["account_age_category"].value_counts()
df["activity_level"].value_counts()
# Out:
# activity_level
# Medium    434
# Low       312
# High      254
# Name: count, dtype: int64

# %%
df.to_csv("synthetic_support_tickets_unique_fe(b).csv", index=False)
